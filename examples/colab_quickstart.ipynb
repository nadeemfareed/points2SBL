# %% [markdown]
# # points2SBL — Google Colab quick start
# Use a GPU runtime when available. For very large acquisitions, pre-tile the source into manageable LAS/LAZ files.

# %%
# !pip -q install points2sbl
# !points2sbl model download
# !points2sbl model status

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
INPUT = "/content/drive/MyDrive/input.las"
OUTPUT = "/content/drive/MyDrive/input_points2sbl_full.las"
# !points2sbl predict --mode full --in_las "$INPUT" --out_las "$OUTPUT"
